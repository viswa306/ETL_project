# %%
import pandas as pd
import requests
import requests ,re

import json
from sqlalchemy import create_engine
from pprint import pprint

# %%
resoources="../Resources/Public_Schools.csv"
data=pd.read_csv(resoources)
data.head()
# Out:
# C:\Users\Viswajani\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            X          Y  FID       NCESID                        NAME  \
# 0 -88.028074  32.791868    1  10168000578       PARAMOUNT JR HIGH SCH
# 1 -87.918717  32.846392    2  10168000864  PETER J KIRKSEY CAREER CTR
# 2 -87.893147  32.838000    3  10168001452           EUTAW PRIMARY SCH
# 3 -87.877214  32.833911    4  10168001520           CARVER MIDDLE SCH
# 4 -87.620561  32.998976    5  10171000588            HALE CO HIGH SCH
#
#                ADDRESS       ADDRESS2        CITY STATE    ZIP  ...  \
# 0               HWY 20  NOT AVAILABLE     BOLIGEE    AL  35443  ...
# 1    836 COUNTY RD 131  NOT AVAILABLE       EUTAW    AL  35462  ...
# 2  212 EUTAW AVE SOUTH  NOT AVAILABLE       EUTAW    AL  35462  ...
# ...

# %%
data=data[["NCESID","NAME","ADDRESS","CITY","STATE","POPULATION","LATITUDE","LONGITUDE","NAICS_DESC","ENROLLMENT"]].copy()
data
# Out:
#               NCESID                         NAME                ADDRESS  \
# 0        10168000578        PARAMOUNT JR HIGH SCH                 HWY 20
# 1        10168000864   PETER J KIRKSEY CAREER CTR      836 COUNTY RD 131
# 2        10168001452            EUTAW PRIMARY SCH    212 EUTAW AVE SOUTH
# 3        10168001520            CARVER MIDDLE SCH     527 GREENSBORO AVE
# 4        10171000588             HALE CO HIGH SCH         50 WILDCAT WAY
# ...              ...                          ...                    ...
# 103476  390146605660     IMAGINE WOODBURY ACADEMY   100 EAST WOODBURY DR
# 103477   10279002155     PIKE CO ALT LEARNING CTR       101 WEST LOVE ST
# 103478  551599002884  WAUWATOSA MONTESSORI SCHOOL   12121 WEST NORTH AVE
# 103479   10282002171             WEDOWEE ELEM SCH  940 WOODLAND AVE WEST
# 103480   10288002192         MT OLIVE PRIMARY SCH            454 HWY 165
#
#                  CITY STATE  POPULATION   LATITUDE  LONGITUDE  \
# ...

# %%
#Check any NA values
data.dropna(how='any')
# Out:
#               NCESID                         NAME                ADDRESS  \
# 0        10168000578        PARAMOUNT JR HIGH SCH                 HWY 20
# 1        10168000864   PETER J KIRKSEY CAREER CTR      836 COUNTY RD 131
# 2        10168001452            EUTAW PRIMARY SCH    212 EUTAW AVE SOUTH
# 3        10168001520            CARVER MIDDLE SCH     527 GREENSBORO AVE
# 4        10171000588             HALE CO HIGH SCH         50 WILDCAT WAY
# ...              ...                          ...                    ...
# 103476  390146605660     IMAGINE WOODBURY ACADEMY   100 EAST WOODBURY DR
# 103477   10279002155     PIKE CO ALT LEARNING CTR       101 WEST LOVE ST
# 103478  551599002884  WAUWATOSA MONTESSORI SCHOOL   12121 WEST NORTH AVE
# 103479   10282002171             WEDOWEE ELEM SCH  940 WOODLAND AVE WEST
# 103480   10288002192         MT OLIVE PRIMARY SCH            454 HWY 165
#
#                  CITY STATE  POPULATION   LATITUDE  LONGITUDE  \
# ...

# %%
data.loc[data['POPULATION']==0]
# Out:
#               NCESID                                 NAME  \
# 1        10168000864           PETER J KIRKSEY CAREER CTR
# 7        10171000875                     HALE CO TECH CTR
# 17       10174000881                NEWVILLE LEARNING CTR
# 18       10174002120                    ABBEVILLE ALT SCH
# 19       10174002122                     HEADLAND ALT SCH
# ...              ...                                  ...
# 103453  273243004545                             LIFESPAN
# 103456  390145905700               NEW DIRECTIONS ACADEMY
# 103465  273178004548  SCHOOL OF ENGINEERING-ARTS AT OLSON
# 103472  390146405669       GAIN PRODUCTIVE SKILLS ACADEMY
# 103477   10279002155             PIKE CO ALT LEARNING CTR
#
#                            ADDRESS           CITY STATE  POPULATION  \
# 1                836 COUNTY RD 131          EUTAW    AL           0
# 7       19875 ALABAMA HWY 69 NORTH     GREENSBORO    AL           0
# ...

# %%
#Delete the Population which is Zero
clear_data=data.loc[data["POPULATION"]>0]
# RENAME THE COLUMNS
rename_data=clear_data.rename(columns={"NCESID":"id","NAME":"name","ADDRESS":"address","CITY":"city","STATE":"state","POPULATION":"population","LATITUDE":"latitude","LONGITUDE":"longitude","NAICS_DESC":"school_type","ENROLLMENT":"enrollment"})

# %%
rename_data.set_index("id", inplace=True)

# %%
rename_data
# Out:
#                                      name                address  \
# id
# 10168000578         PARAMOUNT JR HIGH SCH                 HWY 20
# 10168001452             EUTAW PRIMARY SCH    212 EUTAW AVE SOUTH
# 10168001520             CARVER MIDDLE SCH     527 GREENSBORO AVE
# 10171000588              HALE CO HIGH SCH         50 WILDCAT WAY
# 10171000589           MOUNDVILLE ELEM SCH        537 ALABAMA AVE
# ...                                   ...                    ...
# 10270002179          LAKEWOOD PRIMARY SCH         18 EXPLORER RD
# 390146605660     IMAGINE WOODBURY ACADEMY   100 EAST WOODBURY DR
# 551599002884  WAUWATOSA MONTESSORI SCHOOL   12121 WEST NORTH AVE
# 10282002171              WEDOWEE ELEM SCH  940 WOODLAND AVE WEST
# 10288002192          MT OLIVE PRIMARY SCH            454 HWY 165
#
#                        city state  population   latitude  longitude  \
# id
# 10168000578         BOLIGEE    AL         340  32.791868 -88.028074
# ...

# %% [markdown]
# # Create Database Connection

# %%
connection_string = "postgres:postgre@localhost:5432/public_school"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['schools']

# %%
rename_data.to_sql('schools', con=engine, if_exists='append', index=True)

# %% [markdown]
# # API World Heritage

# %%
url='https://private-portal.opendatasoft.com/api/v2/catalog/datasets/ HTTP/1.1 Authorization: Apikey 7511e8cc6d6dbe65f9bc8dae19e08c08a2cab96ef45a86112d303eee'

# url=" /api/records/1.0/search/?dataset=world-heritage-unesco-list&q=&lang=en&refine.category=Cultural&refine.continent_en=Europe+and+North+America"

# %%
https://examples.opendatasoft.com/api/datasets/1.0/world-heritage-unesco-list/?pretty_print=true&format=json

# %%
#url='https://public.opendatasoft.com/api/v2/catalog/datasets/?apikey=4aa2a7ac6ec62625ae57b9886d556a44173918ad7325abf640cf9fe5 HTTP/1.1'




#url='https://public.opendatasoft.com/api/v2/datasets//world-heritage-unesco-list/?apikey=4aa2a7ac6ec62625ae57b9886d556a44173918ad7325abf640cf9fe5 HTTP/1.1'

#url='https://private.opendatasoft.com/api/datasets/1.0/world-heritage-unesco-list/?pretty_print=true&format=json'
url ='https://private.opendatasoft.com/api/records/1.0/search/?dataset=world-heritage-unesco-list&q=&facet=category&facet=country_en&facet=country_fr&facet=continent_en&facet=continent_fr'

# %%
url='https://examples.opendatasoft.com/api/datasets/1.0/world-heritage-unesco-list/?pretty_print=true&format=json'

# %%
response=requests.get(url).json()

# %%
pprint(response)
# Out:
# {'alternative_exports': [],
#  'attachments': [],
#  'data_visible': True,
#  'datasetid': 'world-heritage-unesco-list',
#  'features': ['geo', 'analyze', 'timeserie'],
#  'fields': [{'label': 'Name (EN)', 'name': 'name_en', 'type': 'text'},
#             {'label': 'Name (FR)', 'name': 'name_fr', 'type': 'text'},
#             {'label': 'Short description (EN)',
#              'name': 'short_description_en',
#              'type': 'text'},
#             {'label': 'Short Description (FR)',
#              'name': 'short_description_fr',
#              'type': 'text'},
#             {'label': 'Justification (EN)',
#              'name': 'justification_en',
#              'type': 'text'},
#             {'label': 'Justification (FR)',
#              'name': 'justification_fr',
#              'type': 'text'},
#             {'label': 'Date inscribed',
#              'name': 'date_inscribed',
#              'type': 'date'},
# ...

# %%
# https://private-portal.opendatasoft.com/api/v2/catalog/datasets/ HTTP/1.1
# Authorization: Apikey 7511e8cc6d6dbe65f9bc8dae19e08c08a2cab96ef45a86112d303eee

url ='https://public-portal.opendatasoft.com/api/v2/catalog/datasets/HTTP/1.1/4aa2a7ac6ec62625ae57b9886d556a44173918ad7325abf640cf9fe5'

# %%
print(response)
# Out:
# <Response [404]>

# %%
url ="https://private-portal.opendatasoft.com/api/v2/world-heritage-unesco-list/?apikey=4aa2a7ac6ec62625ae57b9886d556a44173918ad7325abf640cf9fe5?pretty_print=true&format=json' "

# %%
response=requests.get(url)
response
# Out:
# <Response [404]>

# %%
#https://whc.unesco.org/en/list/
    
    
url='https://whc.unesco.org/en/list//api/v2/catalog/datasets/??dataset=world-heritage-unesco-list&q=&facet=category&facet=country_en&facet=country_fr&facet=continent_en/?apikey=4aa2a7ac6ec62625ae57b9886d556a44173918ad7325abf640cf9fe5 HTTP/1.1'

response=requests.get(url)

# %%
response=requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
# import re, json, requests

# url = 'http://solr.library.ucla.edu/solr/sheetmusic/select/?q=%5C*%20AND%20(url_keyword:http*)&version=2.2&start=0&rows=100&indent=on&facet=true&facet.field=r_date_facetRange&wt=json&json.wrf=jsonp1530647389471'

resp = requests.get(url)
resp_parsed = re.sub(r'^jsonp\d+\(|\)\s+$', '', resp.text)
data = json.loads(resp_parsed)
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-48-87d2ad14fc2d> in <module>
#       5 resp = requests.get(url)
#       6 resp_parsed = re.sub(r'^jsonp\d+\(|\)\s+$', '', resp.text)
# ----> 7 data = json.loads(resp_parsed)
#       8 print(data)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...

# %%
result=response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-44-609db26d4743> in <module>
# ----> 1 result=response.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...

# %%
response = requests.get(url)
print(type(response))
object = json.loads(response.content.decode('utf-8'))
# Out:
# <class 'requests.models.Response'>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-30-7faefe4f1122> in <module>
#       1 response = requests.get(url)
#       2 print(type(response))
# ----> 3 object = json.loads(response.content.decode('utf-8'))
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...

# %%
#https://whc.unesco.org/en/list/
    
    
url='https://whc.unesco.org/en/list//api/v2/catalog/datasets/??dataset=world-heritage-unesco-list&q=&facet=category&facet=country_en&facet=country_fr&facet=continent_en/?apikey=4aa2a7ac6ec62625ae57b9886d556a44173918ad7325abf640cf9fe5 HTTP/1.1?pretty_print=true&format=json'

response=requests.get(url)

# %%
response=requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
#?q=(title:paris OR description:paris) AND records_count >= 50000
result=response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-73-6af3a4afcbc1> in <module>
#       1 #?q=(title:paris OR description:paris) AND records_count >= 50000
# ----> 2 result=response.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ...

# %%
# import requests module 
import requests 
  
# Making a get request 
#response = requests.get('https://api.github.com')
response =requests.get('https://whc.unesco.org/en/list')
  
# print response 
print(response) 
  
# print json content 
print(response.json())
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-53-d2bd8d42bef1> in <module>
#      10
#      11 # print json content
# ---> 12 print(response.json())
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ...

# %%
result =json.loads(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-ebf5f04a0c6d> in <module>
# ----> 1 result =json.loads(response)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not Response

# %%
response=requests.get(url)

# %%
#result= response.json()
print json.loads(response.content.decode('utf-8'))
# Out:
#   File "<ipython-input-98-9d3f9abd603b>", line 2
#     print json.loads(response.content.decode('utf-8'))
#              ^
# SyntaxError: invalid syntax

# %%
response=requests.get('https://whc.unesco.org/en/list//api/v2/catalog/datasets/??dataset=world-heritage-unesco-list&q=&facet=category&facet=country_en&facet=country_fr&facet=continent_en/?apikey=4aa2a7ac6ec62625ae57b9886d556a44173918ad7325abf640cf9fe5 HTTP/1.1')
print(response)
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-105-d36e2ce12dab> in <module>
# ----> 1 print(response.json())
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...

# %%
print(json.dumps(result, indent=4, sort_keys=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-12379fa0fb72> in <module>
# ----> 1 print(json.dumps(results, indent=4, sort_keys=True))
#
# NameError: name 'results' is not defined

# %%
print(url)
# Out:
# https://whc.unesco.org/en/list//api/v2/catalog/datasets/??dataset=world-heritage-unesco-list&q=&facet=category&facet=country_en&facet=country_fr&facet=continent_en/?apikey=4aa2a7ac6ec62625ae57b9886d556a44173918ad7325abf640cf9fe5 HTTP/1.1

# %%
import requests

def url():
    
    response= requests.get(url)
    return(response)
print(response)
# Out:
# <Response [200]>
